# %% [markdown]
# # Merge
#
# A small notebook to merge all of the CSVs into a single, master CSV file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
directory_path = "../raw"
all_files = glob.glob(os.path.join(directory_path, "*.csv"))
all_files
# Out:
# ['../raw\\0_keep_first.csv',
#  '../raw\\0_r2_dupe_keep_first.csv',
#  '../raw\\2021_Jan_Dec.csv',
#  '../raw\\2022_Jan_June.csv',
#  '../raw\\2022_July_Dec.csv',
#  '../raw\\2023_Jan_Dec.csv',
#  '../raw\\2024_Jan_June.csv',
#  '../raw\\2024_July_Dec.csv',
#  '../raw\\2025_Jan_June.csv',
#  '../raw\\2025_July_Dec.csv',
#  '../raw\\airspace_structure_jan_2015_jan_2021.csv',
#  '../raw\\atc_nav_builds_jan_2015_jan_2021.csv',
#  '../raw\\chartorpub_jan_2015_jan_2021.csv',
#  '../raw\\company_policy_jan_2015_jan_2021.csv',
#  '../raw\\env_nonweather_jan_2015_jan_2021.csv',
#  '../raw\\equipment_tooling_jan_2015_jan_2021.csv',
#  '../raw\\humanfactors_jan_2020_jan_2021.csv',
#  '../raw\\incorrect_part_jan_2015_jan_2021.csv',
#  '../raw\\logbook_entry_jan_2015_jan_2021.csv',
#  '../raw\\manuals_jan_2015_jan_2021.csv',
#  '../raw\\mel_jan_2015_jan_2021.csv',
#  '../raw\\merged_2015_2025.csv',
#  '../raw\\merged_2021_2025.csv',
#  '../raw\\procedure_jan_2015_jan_2021.csv',
# ...

# %%
li = []

# Read all CSVs
for filename in all_files:
    df = pd.read_csv(filename, index_col=0, header=[0, 1], low_memory=False)
    li.append(df)

# Combine all DataFrames
df = pd.concat(li, axis=0)

# Remove 'unnamed' column at end (because the CSVs contain ',\n' by default)
df = df.iloc[:, :-1]

# Remove those with duplicate ACNs
unique = df[~df.index.duplicated(keep="first")]

# %%
# unique.to_csv(directory_path + "/merged_2021_2025.csv")
unique.to_csv(directory_path + "/merged_2015_2025.csv")

# %%
directory_path = "./"
all_parsed_files = glob.glob(os.path.join(directory_path, "*.csv"))
all_parsed_files
# Out:
# ['.\\2015_2021_airspace_structure.csv',
#  '.\\2015_2021_atc_nav_builds.csv',
#  '.\\2015_2021_chartorpub.csv',
#  '.\\2015_2021_company_policy.csv',
#  '.\\2015_2021_env_nonweather.csv',
#  '.\\2015_2021_equipment_tooling.csv',
#  '.\\2015_2021_incorrect_part.csv',
#  '.\\2015_2021_logbook_entry.csv',
#  '.\\2015_2021_manuals.csv',
#  '.\\2015_2021_mel.csv',
#  '.\\2015_2021_procedures.csv',
#  '.\\2015_2021_staffing.csv',
#  '.\\2015_2021_weather.csv',
#  '.\\2020_2021_human_factors.csv',
#  '.\\events.csv',
#  '.\\narratives.csv',
#  '.\\rebalance_all.csv',
#  '.\\rebalance_procedure_human_factor.csv']

# %%
augmentation_files = [filename for filename in all_parsed_files if "20" in filename]

display("Concatenating files", augmentation_files)
dfs = [pd.read_csv(f, index_col=0) for f in augmentation_files]
merged = pd.concat(dfs)
merged.index.name = "acn"
print("Num duplicates detected: ", len(merged) - merged.index.nunique())
merged = merged.sample(frac=1.0, random_state=42)
merged
# Out:
# 'Concatenating files'
# ['.\\2015_2021_airspace_structure.csv',
#  '.\\2015_2021_atc_nav_builds.csv',
#  '.\\2015_2021_chartorpub.csv',
#  '.\\2015_2021_company_policy.csv',
#  '.\\2015_2021_env_nonweather.csv',
#  '.\\2015_2021_equipment_tooling.csv',
#  '.\\2015_2021_incorrect_part.csv',
#  '.\\2015_2021_logbook_entry.csv',
#  '.\\2015_2021_manuals.csv',
#  '.\\2015_2021_mel.csv',
#  '.\\2015_2021_procedures.csv',
#  '.\\2015_2021_staffing.csv',
#  '.\\2015_2021_weather.csv',
#  '.\\2020_2021_human_factors.csv']
# Num duplicates detected:  0
#                     Assessments_Primary_Problem  \
# acn
# 1515525                               procedure
# 1665419                               procedure
# 1533455                       airspacestructure
# 1692918  incorrect/notinstalled/unavailablepart
# 1586442                           companypolicy
# ...                                         ...
# 1758577                            humanfactors
# ...

# %%
merged.to_csv("./rebalance_all.csv")
